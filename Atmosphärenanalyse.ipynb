# %% [markdown]
# # Datensatz CO2/CH4/N2O Konzentration in der Atmosphere
# > Datensatzquelle: [*European Environment Agency*](https://www.eea.europa.eu/data-and-maps/daviz/atmospheric-concentration-of-carbon-dioxide-5#tab-chart_5_filters=%7B%22rowFilters%22%3A%7B%7D%3B%22columnFilters%22%3A%7B%22pre_config_polutant%22%3A%5B%22CO2%20(ppm)%22%5D%7D%7D)

# %% [markdown]
# In diesem Notebook werden Sie mit einem Datensatz der European Environment Agency (EEA) arbeiten, der Daten über den zeitlichen Verlauf der Konzentration der Gase Kohlenstoffdioxid, Methan und Distickstoffmonoxid  in der Erdatmosphäre enthält. Hierfür werden Sie insbesondere das Modul **pandas** verwenden. Die notwendigen Befehle finden Sie in dessen offizieller [Dokumentation](https://pandas.pydata.org/docs/user_guide/index.html#user-guide) sowie im offizellen [Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf).
#
# Vervollständigen Sie im folgenden die Codezellen.

# %% [markdown]
# ### Pandas Modul laden
# 1. Importieren Sie das Modul **pandas** unter dem Namen **pd**

# %%
print("Pandas in der Version {} erfolgreich geladen".format(pd.__version__))

# %% [markdown]
# ### Importieren des Datensatzes
# 1. Laden Sie den Datensatz "atmosphere.csv" aus Canvas herunter und kopieren Sie diesen auf der linken Seite von JupyterLab in das gleiche Verzeichnis, wie dieses Notebook (Drag & Drop).
# 2. Vervollständigen Sie die folgende Codezelle, so dass der Datensatz in einen Pandas Dataframe mit der Bezeichnung *atmosphere* geladen wird

# %%
atmosphere = pd.read_...

# %% [markdown]
# ### Überblick verschaffen
# 1. Verschaffen Sie sich einen Überblick, über den Datensatz *atmosphere*, indem Sie sich den Tabellenkopf mit den ersten 5 Zeilen ausgeben lassen.
# 2. Welche Merkmale werden durch den Datensatz erfasst?

# %%
atmosphere.he...

# %% [markdown]
# ### Anzahl der Einträge
# 1. Ermitteln Sie die **Form** des Datensatz *atmosphere*, also dessen Anzahl an Zeilen und Spalten, mit dem passenden Befehl.

# %%
atmosphere.shape

# %% [markdown]
# ### Arithmetisches Mittel der drei Gase über den gesamten Zeitraum
# 1. Ermitteln Sie in den folgenden drei Zellen nacheinander und einzeln, jeweils das arithmetische Mittel der drei erfassten Gase

# %%
atmosphere[...

# %%
atmosphere[...

# %%
atmosphere[...

# %% [markdown]
# ### Statistische Kenngrößen darstellen
# 1. Lassen Sie sich mit einem einzigen Befehl den gesamten DataFrame *atmosphere* statisch **beschreiben**.
# 2. Was war die minimale Konzentration des Treibhausgases Methan in der Erdatmossphäre?

# %%
atmosphere.d...

# %% [markdown]
# ### Einträge filtern mit df.loc[]
# 1. Informieren Sie sich über die Funktionsweise der df.loc[] Funktion.
# 2. Versuchen Sie die folgende Codezelle nachzuvollziehen. Was passiert hier?

# %%
atmosphere.loc[atmosphere['ch4_ppb'] <= 760]

# %% [markdown]
# 1. Verwenden Sie die df.loc[] Funktion um herauszufinden, wann die Methankonzentration in der Atmosphäre die Schwelle von 1775 ppb überschritten hat.

# %%
atmosphere.loc[]

# %% [markdown]
# 1. Recherchieren Sie, wie Sie in der df.loc[] Funktion mehrere Filterbedingungen miteinander verknüpfen können
# 2. Verwenden Sie die df.loc[] Funktion und finden Sie heraus in welchen Jahren die Konzentration von Kohlenstoffdioxid in der Atmosphäre unter 380 ppm lag und die Konzentration Methan über 1772 ppb

# %%
atmosphere.loc[]

# %% [markdown]
# Die folgende Zelle ist für den weiteren Verlauf wichtig und teilt pandas mit, dass die Spalte 'year' als Index genutzt werden soll

# %%
atmosphere.set_index('year', inplace=True)

# %% [markdown]
# ### Visualisierung eines DataFrames
# 1. Mit dem folgenden Befehl plotten Sie den gesamten Inhalt von **atmosphere**

# %%
atmosphere.plot()

# %% [markdown]
# 1. Plotten Sie nun nur die Spalte der Kohlenstoffdioxidkonzentration aus dem Dataframe **atmosphere**

# %%
...

# %% [markdown]
# 1. Plotten Sie die **Änderungsrate** der Kohlenstoffdioxid Konzentration in der Atmosphäre

# %%
atmosphere...

# %% [markdown]
# 1. Bilden Sie über die Änderungsrate ein gleitendes Fenster mit der Länge *n* = 5, in welchem jeweils ein arithmetisches Mittel gebildet wird und plotten Sie diese geglättete Änderungsrate

# %%
atmosphere

# %% [markdown]
# 1. Wechseln Sie die Zellart der nächsten Zelle auf Markdown und schreiben Sie eine Überschrift, sowie eine kurzen Fließtext welcher die letzte Grafik erläutet. Nutzen Sie dabei fettgedruckten Text um besonders wichtige Informationen hervorzuheben.
